# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
x,y=make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=10,random_state=13)

# %%
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [27.86714091]
# -1.135507213089191

# %%
y_pred=lr.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.8820952122527386

# %% [markdown]
# GD MAKE

# %%
class gdregressor:
    def __init__(self,lrt,epochs):
        self.m=100
        self.b=-120
        self.lrt=lrt
        self.epochs=epochs
    def fit(self,x,y):
        for i in range(self.epochs):
            loss_slope_b = -2 * np.sum(y - self.m*x.ravel() - self.b)
            loss_slope_m = -2 * np.sum((y - self.m*x.ravel() - self.b)*x.ravel())
            
            self.b = self.b - (self.lrt * loss_slope_b)
            self.m = self.m - (self.lrt * loss_slope_m)
        print(self.m,self.b)
    def predict(self,x_test):
        return self.m*x_test+self.b

# %%
gd = gdregressor(0.001,50)

# %%
gd.fit(x_train,y_train)
# Out:
# 27.900729871577916 -1.165188597836724

# %%
y_pred = gd.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.8820083403762329
